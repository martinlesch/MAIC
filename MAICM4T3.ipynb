# %% [markdown]
# <a href="https://colab.research.google.com/github/martinlesch/MAIC/blob/main/MAICM4T3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Mar  7 11:44:56 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="li10ckMndt6iSQxdZxQi")
project = rf.workspace("martins-workspace-7mzhv").project("pruebas_maic_m4t3_tarea")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=3 imgsz=640
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 956, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 76, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 144, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 283, in _load
#     self.model, self.ckpt = load_checkpoint(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 1515, in load_checkpoint
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source={dataset.location}/test/images save=True
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 956, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 76, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 144, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 283, in _load
#     self.model, self.ckpt = load_checkpoint(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 1515, in load_checkpoint
# ...

# %%
Image(filename='/content/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2651/3355742904.py in <cell line: 0>()
# ----> 1 Image(filename='/content/runs/detect/train/confusion_matrix.png', width=600)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
Image(filename='/content/runs/detect/train/results.png', width=600)

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/runs/detect/predict2/*.jpg'):
    display(Image(filename=image_path, height=600))
    print ("\n")

# %%
from google.colab import files
from IPython.display import display, Image as IPImage
import os

print('📁 Seleccioná la imagen desde tu computadora...')
uploaded = files.upload()

# Obtener el nombre del archivo subido
imagen_path = list(uploaded.keys())[0]
print(f'✅ Imagen cargada: {imagen_path}')

# Mostrar la imagen original
print('\n🖼️ Imagen original:')
display(IPImage(imagen_path, width=600))

# %%
from ultralytics import YOLO
from IPython.display import display, Image as IPImage
import glob
import os

# Cargar el modelo entrenado
MODEL_PATH = '/content/runs/detect/train/weights/best.pt'
model = YOLO(MODEL_PATH)

# Correr predicción
print(f'🔍 Detectando objetos en: {imagen_path}')
results = model.predict(
    source=imagen_path,
    save=True,          # Guarda la imagen con los bounding boxes
    conf=0.25,          # Umbral de confianza (ajustá según necesites)
    iou=0.45,           # Umbral IoU para NMS
    show_labels=True,
    show_conf=True
)

# Mostrar resultados en consola
print('\n📊 Resultados de detección:')
for r in results:
    boxes = r.boxes
    if boxes is not None and len(boxes) > 0:
        print(f'  → Objetos detectados: {len(boxes)}')
        for box in boxes:
            cls_id = int(box.cls[0])
            conf   = float(box.conf[0])
            label  = model.names[cls_id]
            print(f'     • {label}: {conf:.2%} de confianza')
    else:
        print('  ⚠️ No se detectaron objetos con el umbral actual.')
        print('     Probá bajando conf= a 0.10 o 0.15')

# Encontrar y mostrar la imagen con detecciones
predict_dirs = sorted(glob.glob('/content/runs/detect/predict*'), key=os.path.getmtime)
if predict_dirs:
    ultimo_dir = predict_dirs[-1]
    imagenes_resultado = glob.glob(os.path.join(ultimo_dir, '*.jpg')) + \
                         glob.glob(os.path.join(ultimo_dir, '*.png')) + \
                         glob.glob(os.path.join(ultimo_dir, '*.jpeg'))
    if imagenes_resultado:
        print(f'\n🖼️ Imagen con detecciones (guardada en: {ultimo_dir}):')
        display(IPImage(imagenes_resultado[0], width=600))
    else:
        print('No se encontró imagen de resultado en el directorio.')
else:
    print('No se encontró directorio de predicción.')
